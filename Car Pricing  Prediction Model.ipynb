# %% [raw]
# #Car Pricing prediction based on its features ---
# #with the rise of different car technology based on different features - we wanna predict features based on pricing

# %%
# !pip install sklearn

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import pandas as pd 
# %matplotlib inline

# %%
df= pd.read_csv('C:/Users/HP/Desktop/Datasets folder/CarPrice.csv')

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.drop('car_ID', inplace=True, axis=1)

# %%
df
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            2               audi 100 ls      gas        std       four
# 4            2                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 200         -1           volvo 145e (sw)      gas        std       four
# 201         -1               volvo 144ea      gas      turbo       four
# 202         -1               volvo 244dl      gas        std       four
# 203         -1                 volvo 246   diesel      turbo       four
# 204         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %% [raw]
# #DATA EXPLORATION, ANALYSISM, FEATURE SELECTION

# %%
df
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            2               audi 100 ls      gas        std       four
# 4            2                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 200         -1           volvo 145e (sw)      gas        std       four
# 201         -1               volvo 144ea      gas      turbo       four
# 202         -1               volvo 244dl      gas        std       four
# 203         -1                 volvo 246   diesel      turbo       four
# 204         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %%
df.head()
# Out:
#    symboling                   CarName fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# ...

# %%
df.tail()
# Out:
#      symboling          CarName fueltype aspiration doornumber carbody  \
# 200         -1  volvo 145e (sw)      gas        std       four   sedan
# 201         -1      volvo 144ea      gas      turbo       four   sedan
# 202         -1      volvo 244dl      gas        std       four   sedan
# 203         -1        volvo 246   diesel      turbo       four   sedan
# 204         -1      volvo 264gl      gas      turbo       four   sedan
#
#     drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# 200        rwd          front      109.1      188.8  ...         141
# 201        rwd          front      109.1      188.8  ...         141
# 202        rwd          front      109.1      188.8  ...         173
# 203        rwd          front      109.1      188.8  ...         145
# 204        rwd          front      109.1      188.8  ...         141
#
#      fuelsystem  boreratio stroke compressionratio  horsepower peakrpm  \
# ...

# %%
df.shape
# Out:
# (205, 25)

# %%
df.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   CarName           205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
# ...

# %%
df.describe().transpose()
# Out:
#                   count          mean          std      min      25%  \
# symboling         205.0      0.834146     1.245307    -2.00     0.00
# wheelbase         205.0     98.756585     6.021776    86.60    94.50
# carlength         205.0    174.049268    12.337289   141.10   166.30
# carwidth          205.0     65.907805     2.145204    60.30    64.10
# carheight         205.0     53.724878     2.443522    47.80    52.00
# curbweight        205.0   2555.565854   520.680204  1488.00  2145.00
# enginesize        205.0    126.907317    41.642693    61.00    97.00
# boreratio         205.0      3.329756     0.270844     2.54     3.15
# stroke            205.0      3.255415     0.313597     2.07     3.11
# compressionratio  205.0     10.142537     3.972040     7.00     8.60
# horsepower        205.0    104.117073    39.544167    48.00    70.00
# peakrpm           205.0   5125.121951   476.985643  4150.00  4800.00
# citympg           205.0     25.219512     6.542142    13.00    19.00
# ...

# %%
df.isna().sum()
# Out:
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#checking for outliers ----- 
from matplotlib import pyplot 
from pandas import read_csv

df.plot(kind='box', subplots=True, layout=(4,6), sharex=False, sharey=False)
plt.gcf().set_size_inches(20, 20)
pyplot.show()       #the below shows there is outluiers in wheelbase , carwidth, enginesize, stroke and compression rate with hordse power

# %%
#treating the outliers 
df['wheelbase'] = df['wheelbase'].clip(lower=df['wheelbase'].quantile(0.05), upper=df['wheelbase'].quantile(0.95))

df['carlength'] = df['carlength'].clip(lower=df['carlength'].quantile(0.05), upper=df['carlength'].quantile(0.95))

df['carwidth'] = df['carwidth'].clip(lower= df['carwidth'].quantile(0.05), upper= df['carwidth'].quantile(0.95))

df['enginesize'] = df['enginesize'].clip(lower = df['enginesize'].quantile(0.05), upper = df['enginesize'].quantile(0.95))

df['stroke']  = df['stroke'].clip(lower = df['stroke'].quantile(0.05), upper=df['stroke'].quantile(0.95))

df['compressionratio'] = df['compressionratio'].clip(lower = df['compressionratio'].quantile(0.05), upper=df['compressionratio'].quantile(0.95))

df['horsepower'] = df['horsepower'].clip(lower=df['horsepower'].quantile(0.05), upper=df['horsepower'].quantile(0.95))

df['peakrpm'] = df['peakrpm'].clip(lower=df['peakrpm'].quantile(0.05), upper=df['peakrpm'].quantile(0.95))

df['citympg'] = df['citympg'].clip(lower=df['citympg'].quantile(0.05), upper=df['citympg'].quantile(0.95))

df['highwaympg'] = df['highwaympg'].clip(lower=df['highwaympg'].quantile(0.05), upper=df['highwaympg'].quantile(0.95))

df['price'] = df['price'].clip(lower=df['price'].quantile(0.05), upper=df['price'].quantile(0.95))

# %%
df.plot(kind='box', subplots=True, layout=(4,6), sharex=False, sharey=False)
plt.gcf().set_size_inches(20, 20)
pyplot.show()

# %%
df
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            2               audi 100 ls      gas        std       four
# 4            2                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 200         -1           volvo 145e (sw)      gas        std       four
# 201         -1               volvo 144ea      gas      turbo       four
# 202         -1               volvo 244dl      gas        std       four
# 203         -1                 volvo 246   diesel      turbo       four
# 204         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %% [markdown]
# # DATA EXPLORATORY ANALYSIS

# %% [raw]
# # USING SEABORN TO CREATE JOINTPLOT CHECKING correlation between engine size and price, Does the correlation makes sense?

# %%
sns.jointplot(data=df, x='enginesize', y='price')  #this shows that the engine price have positive linear
#correlation with the price -- though having outliers 
#therefore larger the enginesize the higher the price of cars

# %%
#checking for relationship between highwaympg and fuel type 
sns.barplot(data=df, x='fueltype', y='highwaympg')  #we can see that disel car tends to have high mpg than gas 
#mpg measure efficiency - the higher the mpg the more fuel efficiency is 
#we can see diseal cars tends to have higher highways mpg, therefore more efficient than gas cars
# Out:
# <AxesSubplot:xlabel='fueltype', ylabel='highwaympg'>

# %%
sns.countplot(data=df, x='doornumber', color='yellow')  #indicating four door carsis more higher than two door cars
# Out:
# <AxesSubplot:xlabel='doornumber', ylabel='count'>

# %%
sns.countplot(data=df, x='carbody')
# Out:
# <AxesSubplot:xlabel='carbody', ylabel='count'>

# %%
sns.countplot(data=df, x='enginelocation') #this shows most cars hve their engines located in front of thier cars
# Out:
# <AxesSubplot:xlabel='enginelocation', ylabel='count'>

# %%
sns.countplot(data=df, x='drivewheel')  #this shows the cars has higher number of fwd drivewheel
# Out:
# <AxesSubplot:xlabel='drivewheel', ylabel='count'>

# %%
sns.barplot(data=df, x='enginetype', y='price') #this shows dohcv of engine type has the higest price
# Out:
# <AxesSubplot:xlabel='enginetype', ylabel='price'>

# %%
#checking correlation between engine location and car weight 
sns.displot(df['price'])

# %%
df.corr()
# Out:
#                   symboling  wheelbase  carlength  carwidth  carheight  \
# symboling          1.000000  -0.531237  -0.357973 -0.241507  -0.541038
# wheelbase         -0.531237   1.000000   0.882604  0.827544   0.589282
# carlength         -0.357973   0.882604   1.000000  0.864730   0.498130
# carwidth          -0.241507   0.827544   0.864730  1.000000   0.290439
# carheight         -0.541038   0.589282   0.498130  0.290439   1.000000
# curbweight        -0.227691   0.790268   0.873886  0.881493   0.295572
# enginesize        -0.078939   0.588399   0.699909  0.751452   0.086757
# boreratio         -0.130051   0.516142   0.598754  0.573110   0.171071
# stroke            -0.023355   0.178840   0.146568  0.200468   0.006365
# compressionratio  -0.178555   0.269614   0.168362  0.202459   0.260754
# horsepower         0.066827   0.441150   0.606032  0.655230  -0.062243
# peakrpm            0.277746  -0.341249  -0.270122 -0.226797  -0.320751
# ...

# %%
#plotting scatter matrix for the whole data 
from matplotlib import pyplot
from pandas.plotting  import scatter_matrix

scatter_matrix(df)
plt.gcf().set_size_inches(20,20)
pyplot.show()

# %%
sns.heatmap(data=df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Feature Selection and Feature Engineering on Car Pricing Dataset

# %% [markdown]
# # Rescaling, Standardization and normalization on car princing dataset

# %%
df
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            2               audi 100 ls      gas        std       four
# 4            2                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 200         -1           volvo 145e (sw)      gas        std       four
# 201         -1               volvo 144ea      gas      turbo       four
# 202         -1               volvo 244dl      gas        std       four
# 203         -1                 volvo 246   diesel      turbo       four
# 204         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %%
#checking the scale across the features : 
#symboling min is -2 , maximun is 3 
#wheebase min is 86, maximun - 120 
#carlength min is 141, maximun - 208----- therefor we need to rescale the data bcous its faae wide from each other 
#checking for standardazation across the features ---
#for wheelbase mean= 98.75, , standard deviation = 6--- faar from the mean 
#carlength mean =174, standard deviation = 12------- far from the mean 
#carwidth mean = 68 , standard deviation = 6 ---far friom the mean -- therefore wwe need to re-standardize our data

# %%
df.describe().T
# Out:
#                   count          mean          std      min      25%  \
# symboling         205.0      0.834146     1.245307    -2.00     0.00
# wheelbase         205.0     98.724488     5.154445    93.02    94.50
# carlength         205.0    174.157561    11.250053   157.14   166.30
# carwidth          205.0     65.887610     1.961127    63.60    64.10
# carheight         205.0     53.724878     2.443522    47.80    52.00
# curbweight        205.0   2555.565854   520.680204  1488.00  2145.00
# enginesize        205.0    124.815610    32.545885    90.00    97.00
# boreratio         205.0      3.329756     0.270844     2.54     3.15
# stroke            205.0      3.250683     0.262387     2.64     3.11
# compressionratio  205.0     10.115317     3.820035     7.50     8.60
# horsepower        205.0    102.960000    34.814418    62.00    70.00
# peakrpm           205.0   5121.853659   452.853132  4250.00  4800.00
# citympg           205.0     25.087805     5.996903    16.00    19.00
# ...

# %%
#checking for normalization of data 
df['wheelbase'].plot(kind='density')  #kinda still normal
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#checking for normalization of the data 
df['carlength'].plot(kind='density') #not normal data on the carlength  - so therefore we need to normalize our data
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['curbweight'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
#performing RESCLAINING ON OUR DATA 
from sklearn.preprocessing import MinMaxScaler
from numpy import set_printoptions


X=df[['symboling', 'wheelbase', 'carlength', 'carwidth','carheight','curbweight', 'enginesize','boreratio', 'stroke',
        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']]
Y= df['price']

scaler=MinMaxScaler(feature_range=(0,1))
rescaleX=scaler.fit_transform(X)

#setting options 
set_printoptions(precision=3)
rescaleX
# Out:
# array([[1.   , 0.   , 0.297, ..., 0.434, 0.238, 0.24 ],
#        [1.   , 0.   , 0.297, ..., 0.434, 0.238, 0.24 ],
#        [0.6  , 0.087, 0.358, ..., 0.434, 0.143, 0.192],
#        ...,
#        [0.2  , 0.947, 0.807, ..., 0.723, 0.095, 0.048],
#        [0.2  , 0.947, 0.807, ..., 0.318, 0.476, 0.24 ],
#        [0.2  , 0.947, 0.807, ..., 0.665, 0.143, 0.144]])

# %%
#converting rescaleX data back to Dataframe and adding the outcome virable price 
rescaleXDF= pd.DataFrame(rescaleX, columns=['symboling','wheelbase', 'carlength', 'carwidth','carheight', 'curbweight','enginesize',
                                            'boreratio', 'stroke','compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg'])
print(rescaleXDF)
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          1.0   0.000000   0.297297  0.072886   0.083333    0.411171
# 1          1.0   0.000000   0.297297  0.072886   0.083333    0.411171
# 2          0.6   0.087161   0.358491  0.276968   0.383333    0.517843
# 3          0.8   0.399293   0.496175  0.379009   0.541667    0.329325
# 4          0.8   0.375736   0.496175  0.408163   0.541667    0.518231
# ..         ...        ...        ...       ...        ...         ...
# 200        0.2   0.946996   0.807241  0.772595   0.641667    0.567882
# 201        0.2   0.946996   0.807241  0.758017   0.641667    0.605508
# 202        0.2   0.946996   0.807241  0.772595   0.641667    0.591156
# 203        0.2   0.946996   0.807241  0.772595   0.641667    0.670675
# 204        0.2   0.946996   0.807241  0.772595   0.641667    0.610551
#
#      enginesize  boreratio  stroke  compressionratio  horsepower   peakrpm  \
# ...

# %%
rescaleXDF
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          1.0   0.000000   0.297297  0.072886   0.083333    0.411171
# 1          1.0   0.000000   0.297297  0.072886   0.083333    0.411171
# 2          0.6   0.087161   0.358491  0.276968   0.383333    0.517843
# 3          0.8   0.399293   0.496175  0.379009   0.541667    0.329325
# 4          0.8   0.375736   0.496175  0.408163   0.541667    0.518231
# ..         ...        ...        ...       ...        ...         ...
# 200        0.2   0.946996   0.807241  0.772595   0.641667    0.567882
# 201        0.2   0.946996   0.807241  0.758017   0.641667    0.605508
# 202        0.2   0.946996   0.807241  0.772595   0.641667    0.591156
# 203        0.2   0.946996   0.807241  0.772595   0.641667    0.670675
# 204        0.2   0.946996   0.807241  0.772595   0.641667    0.610551
#
#      enginesize  boreratio  stroke  compressionratio  horsepower   peakrpm  \
# ...

# %%
df['price']
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
#adding back the outcome virable 
rescaleXDF['price']=df['price']
print(rescaleXDF)
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          1.0   0.000000   0.297297  0.072886   0.083333    0.411171
# 1          1.0   0.000000   0.297297  0.072886   0.083333    0.411171
# 2          0.6   0.087161   0.358491  0.276968   0.383333    0.517843
# 3          0.8   0.399293   0.496175  0.379009   0.541667    0.329325
# 4          0.8   0.375736   0.496175  0.408163   0.541667    0.518231
# ..         ...        ...        ...       ...        ...         ...
# 200        0.2   0.946996   0.807241  0.772595   0.641667    0.567882
# 201        0.2   0.946996   0.807241  0.758017   0.641667    0.605508
# 202        0.2   0.946996   0.807241  0.772595   0.641667    0.591156
# 203        0.2   0.946996   0.807241  0.772595   0.641667    0.670675
# 204        0.2   0.946996   0.807241  0.772595   0.641667    0.610551
#
#      enginesize  boreratio  stroke  compressionratio  horsepower   peakrpm  \
# ...

# %%
#checking if its has RESHAPED 
rescaleXDF.describe().T   #perfectly resclaed
# Out:
#                   count          mean          std     min          25%  \
# symboling         205.0      0.566829     0.249061     0.0     0.400000
# wheelbase         205.0      0.335953     0.303560     0.0     0.087161
# carlength         205.0      0.433900     0.286845     0.0     0.233554
# carwidth          205.0      0.333471     0.285879     0.0     0.072886
# carheight         205.0      0.493740     0.203627     0.0     0.350000
# curbweight        205.0      0.414106     0.201971     0.0     0.254849
# enginesize        205.0      0.313090     0.292679     0.0     0.062950
# boreratio         205.0      0.564111     0.193460     0.0     0.435714
# stroke            205.0      0.610683     0.262387     0.0     0.470000
# compressionratio  205.0      0.182634     0.266762     0.0     0.076816
# horsepower        205.0      0.344781     0.293051     0.0     0.067340
# peakrpm           205.0      0.503962     0.261765     0.0     0.317919
# ...

# %%
#correcting standardization error -- Re-standardization
from sklearn.preprocessing import StandardScaler
from numpy import set_printoptions

X=rescaleXDF[['symboling','wheelbase', 'carlength', 'carwidth','carheight', 'curbweight', 'enginesize','boreratio', 'stroke',
        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']]
Y=rescaleXDF['price']

scaler2=StandardScaler().fit(X)
rescaleStan= scaler2.transform(X)

#summarize transform data 
set_printoptions(precision=3)
print(rescaleStan)
# Out:
# [[ 1.743 -1.109 -0.477 ... -0.27  -0.683 -0.613]
#  [ 1.743 -1.109 -0.477 ... -0.27  -0.683 -0.613]
#  [ 0.134 -0.822 -0.264 ... -0.27  -1.018 -0.778]
#  ...
#  [-1.476  2.018  1.305 ...  0.837 -1.185 -1.274]
#  [-1.476  2.018  1.305 ... -0.712  0.152 -0.613]
#  [-1.476  2.018  1.305 ...  0.616 -1.018 -0.943]]

# %%
#converting rescaled Standard deviation to Dataframe and adding the price 
rescaleStanDF= pd.DataFrame(rescaleStan, columns=['symboling','wheelbase', 'carlength', 'carwidth','carheight','curbweight',
                                                  'enginesize','boreratio', 'stroke','compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg'])
print(rescaleStan)

#adding price 
rescaleStanDF['price']=rescaleXDF['price']

print(rescaleStanDF)
# Out:
# [[ 1.743 -1.109 -0.477 ... -0.27  -0.683 -0.613]
#  [ 1.743 -1.109 -0.477 ... -0.27  -0.683 -0.613]
#  [ 0.134 -0.822 -0.264 ... -0.27  -1.018 -0.778]
#  ...
#  [-1.476  2.018  1.305 ...  0.837 -1.185 -1.274]
#  [-1.476  2.018  1.305 ... -0.712  0.152 -0.613]
#  [-1.476  2.018  1.305 ...  0.616 -1.018 -0.943]]
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0     1.743470  -1.109422  -0.477391 -0.913753  -2.020417   -0.014566
# 1     1.743470  -1.109422  -0.477391 -0.913753  -2.020417   -0.014566
# 2     0.133509  -0.821588  -0.263537 -0.198130  -0.543527    0.514882
# 3     0.938490   0.209168   0.217636  0.159681   0.235942   -0.420797
# 4     0.938490   0.131375   0.217636  0.261913   0.235942    0.516807
# ..         ...        ...        ...       ...        ...         ...
# 200  -1.476452   2.017853   1.304730  1.539811   0.728239    0.763241
# 201  -1.476452   2.017853   1.304730  1.488695   0.728239    0.949992
# ...

# %%
#checking the re-standardized data 
rescaleStanDF.describe().T  #well standardize
# Out:
#                   count          mean          std          min          25%  \
# symboling         205.0 -2.057974e-16     1.002448    -2.281433    -0.671472
# wheelbase         205.0  4.332578e-18     1.002448    -1.109422    -0.821588
# carlength         205.0  2.664535e-16     1.002448    -1.516368    -0.700156
# carwidth          205.0  4.115949e-17     1.002448    -1.169332    -0.913753
# carheight         205.0  2.827007e-16     1.002448    -2.430664    -0.707626
# curbweight        205.0 -7.040439e-17     1.002448    -2.055348    -0.790449
# enginesize        205.0  2.959692e-16     1.002448    -1.072358    -0.856750
# boreratio         205.0 -3.032804e-16     1.002448    -2.923049    -0.665314
# stroke            205.0 -1.137302e-17     1.002448    -2.333108    -0.537478
# compressionratio  205.0  1.517756e-16     1.002448    -0.686308    -0.397647
# horsepower        205.0  8.313133e-17     1.002448    -1.179404    -0.949052
# ...

# %%
#working the normalization 
from sklearn.preprocessing import Normalizer
from numpy import set_printoptions

X=rescaleStanDF[['symboling','wheelbase', 'carlength', 'carwidth','carheight','curbweight','enginesize','boreratio', 'stroke',
        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']]
Y=rescaleStanDF['price']

scaler3=Normalizer().fit(X)
reNormalX= scaler3.transform(X)
#setting options 

set_printoptions(precision=3)
print(reNormalX)
# Out:
# [[ 0.443 -0.282 -0.121 ... -0.068 -0.173 -0.156]
#  [ 0.443 -0.282 -0.121 ... -0.068 -0.173 -0.156]
#  [ 0.038 -0.232 -0.075 ... -0.076 -0.288 -0.22 ]
#  ...
#  [-0.319  0.436  0.282 ...  0.181 -0.256 -0.275]
#  [-0.296  0.404  0.261 ... -0.143  0.031 -0.123]
#  [-0.354  0.484  0.313 ...  0.148 -0.244 -0.226]]

# %%
#converting reNormalX to Dataframe and adding the price 
reNormalXDF= pd.DataFrame(reNormalX, columns=['symboling','wheelbase', 'carlength', 'carwidth','carheight','curbweight','enginesize','boreratio', 'stroke',
        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg'])
print(reNormalXDF)

#adding the price
reNormalXDF['price']= rescaleStanDF['price']
print(reNormalXDF)
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0     0.442578  -0.281626  -0.121185 -0.231955  -0.512881   -0.003698
# 1     0.442578  -0.281626  -0.121185 -0.231955  -0.512881   -0.003698
# 2     0.037750  -0.232309  -0.074517 -0.056023  -0.153686    0.145586
# 3     0.559908   0.124791   0.129843  0.095267   0.140764   -0.251050
# 4     0.363877   0.050938   0.084383  0.101550   0.091481    0.200380
# ..         ...        ...        ...       ...        ...         ...
# 200  -0.375754   0.513539   0.332051  0.391878   0.185335    0.194243
# 201  -0.332711   0.454713   0.294015  0.335470   0.164105    0.214076
# 202  -0.318805   0.435707   0.281726  0.332486   0.157246    0.189747
# 203  -0.295660   0.404075   0.261272  0.308347   0.145830    0.255006
# 204  -0.353842   0.483592   0.312688  0.369026   0.174527    0.233670
#
#      enginesize  boreratio    stroke  compressionratio  horsepower   peakrpm  \
# ...

# %%
#checking normalized data 
reNormalXDF.describe().T
# Out:
#                   count          mean          std          min          25%  \
# symboling         205.0      0.007602     0.300114    -0.609507    -0.222779
# wheelbase         205.0     -0.029612     0.247281    -0.412654    -0.232309
# carlength         205.0     -0.013405     0.255868    -0.478239    -0.208794
# carwidth          205.0     -0.030628     0.249594    -0.560765    -0.250859
# carheight         205.0     -0.004625     0.287023    -0.634829    -0.202299
# curbweight        205.0     -0.037227     0.246125    -0.440644    -0.262082
# enginesize        205.0     -0.030156     0.249587    -0.338633    -0.250372
# boreratio         205.0     -0.009088     0.276032    -0.679995    -0.257870
# stroke            205.0      0.018564     0.312722    -0.835107    -0.124925
# compressionratio  205.0     -0.038597     0.218931    -0.351215    -0.126837
# horsepower        205.0     -0.027656     0.261058    -0.418394    -0.243900
# ...

# %%
reNormalXDF
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0     0.442578  -0.281626  -0.121185 -0.231955  -0.512881   -0.003698
# 1     0.442578  -0.281626  -0.121185 -0.231955  -0.512881   -0.003698
# 2     0.037750  -0.232309  -0.074517 -0.056023  -0.153686    0.145586
# 3     0.559908   0.124791   0.129843  0.095267   0.140764   -0.251050
# 4     0.363877   0.050938   0.084383  0.101550   0.091481    0.200380
# ..         ...        ...        ...       ...        ...         ...
# 200  -0.375754   0.513539   0.332051  0.391878   0.185335    0.194243
# 201  -0.332711   0.454713   0.294015  0.335470   0.164105    0.214076
# 202  -0.318805   0.435707   0.281726  0.332486   0.157246    0.189747
# 203  -0.295660   0.404075   0.261272  0.308347   0.145830    0.255006
# 204  -0.353842   0.483592   0.312688  0.369026   0.174527    0.233670
#
#      enginesize  boreratio    stroke  compressionratio  horsepower   peakrpm  \
# ...

# %% [markdown]
# BEFORE NORMALIZATION

# %%
df['enginesize'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# AFTER NORMALIZATION

# %%
reNormalXDF['enginesize'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# BEFORE NORMALIZATION

# %%
df['carlength'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# AFTER NORMALIZATION

# %%
reNormalXDF['carlength'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# #BEFORE NORMALIZATION

# %%
df['carheight'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# AFTER NORMALIZATION

# %%
reNormalXDF['carheight'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [raw]
# reNormalXDF

# %% [markdown]
# # Converting Categorical virable to numerical

# %%
#using label encoding to encoding categorical virable to numericval 
df.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
#df['CarName'].unique()

# %%
df['fueltype'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
df['aspiration'].unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
df['doornumber'].unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
df['carbody'].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
df['drivewheel'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df['enginelocation'].unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
df['enginetype'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf', 'dohcv'], dtype=object)

# %%
df['cylindernumber'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
df['fuelsystem'].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
#Label conversion 
encodeList=['CarName', 'fueltype', 'aspiration', 'doornumber','carbody', 'drivewheel', 'enginelocation', 'enginetype',
           'cylindernumber', 'fuelsystem']

from sklearn.preprocessing import LabelEncoder

enCode= LabelEncoder()
for x in encodeList:
    df[x]= enCode.fit_transform(df[x])

# %%
P=df[encodeList]

# %%
P
# Out:
#      CarName  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0          2         1           0           1        0           2
# 1          3         1           0           1        0           2
# 2          1         1           0           1        2           2
# 3          4         1           0           0        3           1
# 4          5         1           0           0        3           0
# ..       ...       ...         ...         ...      ...         ...
# 200      139         1           0           0        3           2
# 201      138         1           1           0        3           2
# 202      140         1           0           0        3           2
# 203      142         0           1           0        3           2
# 204      143         1           1           0        3           2
#
#      enginelocation  enginetype  cylindernumber  fuelsystem
# 0                 0           0               2           5
# ...

# %% [markdown]
# # Concatenating the Normalized table and the encoded table

# %%
P.columns
# Out:
# Index(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber',
#        'fuelsystem'],
#       dtype='object')

# %%
reNormalXDF.columns
# Out:
# Index(['symboling', 'wheelbase', 'carlength', 'carwidth', 'carheight',
#        'curbweight', 'enginesize', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
#joining two tables 
for x in reNormalXDF.columns:
    P[x]= reNormalXDF[x]
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_18612/1178968343.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   P[x]= reNormalXDF[x]

# %%
P
# Out:
#      CarName  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0          2         1           0           1        0           2
# 1          3         1           0           1        0           2
# 2          1         1           0           1        2           2
# 3          4         1           0           0        3           1
# 4          5         1           0           0        3           0
# ..       ...       ...         ...         ...      ...         ...
# 200      139         1           0           0        3           2
# 201      138         1           1           0        3           2
# 202      140         1           0           0        3           2
# 203      142         0           1           0        3           2
# 204      143         1           1           0        3           2
#
#      enginelocation  enginetype  cylindernumber  fuelsystem  ...  curbweight  \
# ...

# %%
sns.heatmap(P.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(reNormalXDF.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#checking corr bnetwwen the horsepoer and enginesize 
sns.lmplot(data=P, y='horsepower', x='enginesize') #liner correlated - this means as horse power (power the car 
                                                                    # produces its influences the enginesize increases )

# %%
#checkingfor corr betwween enginessize and price sns
sns.lmplot(data=P, y='price', x='enginesize')  #linear correlated, this means as enginesize increases,
#ts influences the price of the car

# %%
#do stroke has influences car engine 
sns.lmplot(data=P, x='stroke', y='enginesize')   #no relation between car enginesize and stroke

# %%
#do stroke influence compression ration 
sns.lmplot(data=P, x='stroke', y='compressionratio')  
#there is no relation betwee n stroke and compression ration

# %% [markdown]
# # Using SKLEARN TO TRAIN OUR MODEL

# %%
P.columns
# Out:
# Index(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber',
#        'fuelsystem', 'symboling', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %% [markdown]
# # Assigning features to X and Y

# %%
X= P[['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
       'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber',
       'fuelsystem', 'symboling', 'wheelbase', 'carlength', 'carwidth',
       'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke',
       'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']]

y= reNormalXDF['price']

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,  X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=1)

# %%
print(X_train.head())
# Out:
#      CarName  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 106       70         1           0           1        2           2
# 90        73         0           0           1        3           1
# 147      111         1           0           0        4           1
# 185      137         1           0           0        3           1
# 95        74         1           0           1        2           1
#
#      enginelocation  enginetype  cylindernumber  fuelsystem  ...  carheight  \
# 106               0           5               3           5  ...  -0.456233
# 90                0           3               2           3  ...   0.062776
# 147               0           4               2           5  ...  -0.106443
# 185               0           3               2           5  ...   0.415603
# 95                0           3               2           1  ...  -0.062594
#
#      curbweight  enginesize  boreratio    stroke  compressionratio  \
# ...

# %% [markdown]
# # Creating and Train Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
lm= LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lm.score(X_train, y_train)  #checking the R-squared
# Out:
# 0.841151833489265

# %%
lm.score(X_test, y_test)
# Out:
# 0.7734486603095052

# %% [markdown]
# # Model Evaluation

# %%
print(lm.intercept_)
# Out:
# 13781.319627448695

# %%
#printing the coefficient, the coeffiecent will relate with each features in our data 
lm.coef_
# Out:
# array([  -35.109,   986.434,    53.571, -1001.846,  -394.577,  3166.82 ,
#        13539.602,   305.112,  -927.969,   -39.798,  -677.809, -3260.712,
#        -2268.651,  9488.561,  2895.095,  7656.167,  3707.676, -2273.543,
#        -2504.119,  3393.251,  5024.683,  -404.406, -7210.506,  6639.322])

# %%
#checking training column 
X_test.columns
# Out:
# Index(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber',
#        'fuelsystem', 'symboling', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg'],
#       dtype='object')

# %%
#creating a dataframe for this train columns to makes it well structures v
cdf = pd.DataFrame(lm.coef_, X_train.columns, columns=['Coefficient'])

# %%
cdf
# Out:
#                    Coefficient
# CarName             -35.108581
# fueltype            986.433734
# aspiration           53.571077
# doornumber        -1001.845592
# carbody            -394.577250
# drivewheel         3166.819576
# enginelocation    13539.602348
# enginetype          305.112455
# cylindernumber     -927.969327
# fuelsystem          -39.798121
# symboling          -677.809053
# wheelbase         -3260.711589
# carlength         -2268.651045
# carwidth           9488.561326
# carheight          2895.094676
# curbweight         7656.167402
# enginesize         3707.675519
# boreratio         -2273.543181
# stroke            -2504.118781
# compressionratio   3393.251024
# horsepower         5024.682760
# peakrpm            -404.405651
# citympg           -7210.505694
# highwaympg         6639.322328

# %% [markdown]
# Interpreting the coefficients:
#
# Holding all other features fixed, a 1 unit increase in enginesize will lead to 3707. carwidth is associated with an *increase of  9488∗.𝐻𝑜𝑙𝑑𝑖𝑛𝑔𝑎𝑙𝑙𝑜𝑡ℎ𝑒𝑟𝑓𝑒𝑎𝑡𝑢𝑟𝑒𝑠𝑓𝑖𝑥𝑒𝑑, 1 unit increae in carlength
# will be -2268∗
# . Holding all other features fixed, a 1 unit increase in horsepower is associated with an *increase of 5024 *. Does this make sense?

# %% [markdown]
# # Predicting the  Model

# %%
Predictions= lm.predict(X_test)

# %%
Predictions
# Out:
# array([ 7859.029,  4265.435,  5780.804,  7649.334,  7509.535, 24832.135,
#         5600.809,  6632.939,  6837.913, 11825.751, 15174.382, 15807.115,
#        16432.886,  9150.48 , 15015.838, 12776.623,  3048.305,  8053.1  ,
#        14697.173,  8925.416,  9349.61 ,  8267.958, 15095.196,  6336.788,
#        11535.916,  7889.533, 14170.637,  9771.53 ,  7160.607,  8377.515,
#         6403.325, 12176.806, 22517.916, 12412.746, 19328.448,  8901.086,
#         8278.482, 21682.212, 12724.836, 17775.952,  7087.724])

# %%
#comparing it to the correct price of car 
y_test
# Out:
# 78      6669.0
# 97      7999.0
# 151     6338.0
# 44      8916.5
# 40     10295.0
# 67     25552.0
# 98      8249.0
# 18      6197.0
# 152     6488.0
# 62     10245.0
# 4      17450.0
# 172    17669.0
# 197    16515.0
# 38      9095.0
# 29     12964.0
# 170    11199.0
# 190     9980.0
# 33      6529.0
# 136    18150.0
# 145    11259.0
# 173     8948.0
# 31      6855.0
# 11     16925.0
# 119     7957.0
# 169     9989.0
# 34      7129.0
# 84     14489.0
# 184     7995.0
# 120     6229.0
# 35      7295.0
# 163     8058.0
# 28      8921.0
# 16     32472.4
# 130     9295.0
# 116    17950.0
# 182     7775.0
# 27      8558.0
# 47     32250.0
# 58     15645.0
# 204    22625.0
# 138     6197.0
# Name: price, dtype: float64

# %% [markdown]
# # Another way of comparing original car price to the predicted car price is by doing scatter plot

# %%
plt.scatter(y_test, Predictions)

# %%
#Creating Residual Histogram between y-test and prediction 
sns.distplot(y_test-Predictions)
# Out:
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# Regression Evaluation Metrics Here are three common evaluation metrics for regression problems:
#
# Mean Absolute Error (MAE) is the mean of the absolute value of the errors:
#
# 1𝑛∑𝑖=1𝑛|𝑦𝑖−𝑦̂ 𝑖|
#
# Mean Squared Error (MSE) is the mean of the squared errors:
#
# 1𝑛∑𝑖=1𝑛(𝑦𝑖−𝑦̂ 𝑖)2
#
# Root Mean Squared Error (RMSE) is the square root of the mean of the squared errors:
#
# 1𝑛∑𝑖=1𝑛(𝑦𝑖−𝑦̂ 𝑖)2⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯⎯
#
# Comparing these metrics:
#
# MAE is the easiest to understand, because it's the average error. MSE is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world. RMSE is even more popular than MSE, because RMSE is interpretable in the "y" units. All of these are loss functions, because we want to minimize them.

# %% [markdown]
# # Calculating  Evaluation Metrics

# %%
from sklearn import metrics
from sklearn.metrics import r2_score

# %%
metrics.mean_absolute_error(y_test, Predictions)  #the model is making 2172 errors on the average
# Out:
# 2172.9359509964515

# %%
metrics.mean_squared_error(y_test, Predictions)
# Out:
# 9872537.79248448

# %%
#checking for root mean square error 
np.sqrt(metrics.mean_squared_error(y_test, Predictions)) #model is maKaking 3142 error on average
# Out:
# 3142.059482645814

# %%
r2= (r2_score(y_test, Predictions))  #rechecking r-sqauared  using aniother method

# %%
print("R-square: {:.2f}".format(r2)) #An R-squared value of 0.77 indicates that 76% of the variance in the 
#dependent variable is explained by the independent variable(s) used in the linear regression model.
#In other words, the independent variable(s) used in the model can explain 76% of the variation in the dependent variable.
# Out:
# R-square: 0.77
